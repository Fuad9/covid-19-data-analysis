# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
data = pd.read_csv(r"F:/data-science-projects/arizona-history.csv")

# %%
data.head()
# Out:
#          date state    death  deathConfirmed  deathIncrease  deathProbable  \
# 0  2021-03-07    AZ  16328.0         14403.0              5         1925.0
# 1  2021-03-06    AZ  16323.0         14395.0             54         1928.0
# 2  2021-03-05    AZ  16269.0         14339.0             84         1930.0
# 3  2021-03-04    AZ  16185.0         14264.0             96         1921.0
# 4  2021-03-03    AZ  16089.0         14176.0             29         1913.0
#
#    hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0         57907                   57907                  963.0
# 1         57863                   57863                  966.0
# 2         57819                   57819                 1043.0
# 3         57747                   57747                 1072.0
# 4         57697                   57697                 1165.0
#
#    hospitalizedIncrease  ...  totalTestResults  totalTestResultsIncrease  \
# ...

# %%
sns.relplot(x="death", y="deathConfirmed", data=data)
